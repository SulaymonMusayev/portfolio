# %%
#1
yosh=int(input("yoshingizni kiriting "))
if yosh>21:
    print("Kattalar guruhiga hush kelibsiz")
else:
    print("Siz yoshlar guruhiga mansubsiz")

# %%
#2
parol=input("Parolni kiriting ")
if parol=="python123":
    print("Parol to'g'ri")
else:
    print("Parol noto'g'ri")

# %%
#3
son=int(input("Biror son kiriting "))
if son>0 and son%2==0:
  print("Bu son musbat juft")
elif son<0 and son%2!=0:
  print("Bu son manfiy toq")

# %%
#4
son1=int(input("Birinchi sonni kiriting "))
son2=int(input("Ikkinchi sonni kiriting "))
if son1>0 and son2>0:
    print(f"Yigindi --> {son1+son2}")
else:
    print(f"Farqi --> {son1-son2}")

# %%
#5
baho=int(input("Olgan bahoyingizni kiriting "))
if baho<50:
    print("Qoniqarsiz")
elif baho<69:
    print("Qoniqarli")
elif baho<89:
    print("Yaxshi")
elif baho>89:
    print("A'lo")

# %%
#6
ish=input("Bugun ishmi ha/yoq ")
dam=input("Bugun dammi ha/yoq ")
if ish=="ha" and dam=="yoq":
    print("Bugun ish kuni ekan")
elif ish=="yoq" and dam=="ha":
    print("Bugun dam olish ekan")

# %%
#7
son=int(input("Biror sonni kiriting "))
if son%6==0:
    print("To'liq bo'linadi")
else:
    print("To'liq bo'linmaydi")

# %%
#8
ismlar=[]
for i in range(3):
    ism=input(f"{i+1}-ismni kiriting ")
    ismlar.append(ism)
print(ismlar)
eng_uzun_soz=max(ismlar, key=len)
print(f"Eng uzun so'z: {eng_uzun_soz}")

# %%
#1
yosh=int(input("Yoshingizni kiriting "))
if yosh>18:
    print("Kirishga ruxsat")
else:
    print("Siz voyaga yetmagansiz")

# %%
#2
baho=float(input("Olgan bahoyingizni kiriting "))
if baho<60:
    print("F")
elif baho<69:
    print("D")
elif baho<79:
    print("C")
elif baho<89:
    print("B")
else:
    print("A")

# %%
#3
tel=input("Telefon raqamingizni kiriting ")
if tel.startswith("998"):
    print("Bu O'zbekiston raqami")
else:
    print("Bu O'zbekiston raqami emas")

# %%
#4
odamlar=int(input("Tashrif buyurgan odamlar sonini kiriting "))
if odamlar==0:
    print("Hech kim kelmagan")
elif odamlar==1:
    print("Bitta mehmon kelgan")
elif odamlar<=5:
    print("Kam mehmon kelgan")
else:
    print("Kop mehmon kelgan")

# %%
#5
yoshlari=[]
for i in range(3):
    yosh=int(input(f"{i+1}-kishining yoshini kiriting "))
yoshlari.append(yosh)
max_yosh=max(yoshlari)
print(f"Eng katta odamning yoshi {max_yosh} ekan")

# %%
#6
ob_havo=input("Ob havoni kiriting:")
ob_havo=ob_havo.lower()
if ob_havo=='quyoshli':
    print("Koproq suv iching va quyoshdan saqlaning")
elif ob_havo=='yomgirli' or ob_havo=="yomg'irli":
    print("Soyabonni unutmang")
elif ob_havo=="qorli":
    print("Qalinroq kiyining")

# %%
#7
yosh=int(input("Yoshingizni kiriting "))
mahsulot=input("Mahsulot turini kiriting")
if mahsulot=='dori' and yosh>65:
    print("Sizga 15% chegirma bor")
else:
    print("Umumiy summa ...")

# %%
#8
son=int(input("Biror sonni kiriting "))
if son>0:
    print("Son musbat ekan")
elif son<0:
    print("Son manfiy ekan")
elif son==0:
    print("Son neytral")

# %%
#9
son1=int(input("Birinchi sonni kiriting "))
son2=int(input("Ikkinchi sonni kiriting "))
if son1>son2:
    print(f"{son1} {son2}dan {son1-son2}ga katta")
elif son1<son2:
    print(f"{son2} {son1}dan {son2-son1}ga katta")

# %%
#10
son=int(input("Biror sonni kiriting "))
if son%3==0:
    print("Son 3ga bo'linadi")
elif son%5==0:
    print("Son 5ga bo'linadi")
elif son%5==0 and son%3==0:
    print("Son 3ga ham 5ga ham bo'linadi")
else:
    print("Son 3ga ham 5ga ham bo'linmaydi")
