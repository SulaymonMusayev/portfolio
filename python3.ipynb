# %%
#1
for i in range(10):
    print(i)

# %%
#2
mevalar = []
for i in range(5):
    meva = input(f"{i+1}-mevani savatga kiriting: ")
    mevalar.append(meva)

for meva in mevalar:
    print(f"Siz kiritgan meva: {meva}")

# %%
#3
soz=["P", "Y", "T", "H", "O", "N"]
for i in soz:
    print(i)

# %%
#4
print(list(range(10,0,-1)))

# %%
#5
for i in range(1,51):
  print(i)

# %%
#6
while True:
    ism=input("Ismingizni kiriting ")
    if ism=='stop':
      break

# %%
#7
while True:
    raqam=int(input("Raqam kiriting "))
    if raqam==0:
        break
