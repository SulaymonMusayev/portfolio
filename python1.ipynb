# %%
#1
ism=input("Ismingizni kiriting ")
kasb=input("Kasbingizni yozing ")
print(f"Men {ism}man. Kasbim - {kasb}")
# Out:
# Ismingizni kiriting  a
# Kasbingizni yozing  s
# Men aman. Kasbim - s

# %%
#2
yosh=int(input("Yoshingizni kiriting"))
x=yosh+10
print(f"Siz 10 yildan keyin {x} yosh bo'lasiz")

# %%
#3
familiya=input("Familiyangizni kiriting")
ism=input("Ismingizni kiriting")
print(f"To'liq ism: {familiya} {ism}")

# %%
#4
kvadrat=int(input("Biror kvadrat tomonini kiriting" ))
print(f"U kvadratning yuzi -> {kvadrat**2}")

# %%
#5
sinfdosh1=input("Birinchi sinfdoshingiz ismini kiriting ")
sinfdosh2=input("Ikkinchi sinfdoshingiz ismini kiriting ")
sinfdosh3=input("Uchinchi sinfdoshingiz ismini kiriting ")
print(f"Sizning sinfdoshlaringiz: {sinfdosh1}, {sinfdosh2}, {sinfdosh3}")

# %%
#6
print("😃 Salom, Python! 🚀")

# %%
#7
a=10
b="10"
c=10.0
print(f"aning ma'lumot turi {type(a)}")
print(f"bning ma'lumot turi {type(b)}")
print(f"cning malumot turi {type(c)}")
if a==b:
  print("a=b")
elif a==c:
  print("a=c")
else:
  print("a bga ham cga ham teng emas")

# %%
#8
son1=float(input("Birinchi sonni kiriting "))
son2=float(input("Ikkinchi sonni kiriting "))
print(f"{son1}ni {son2}ga bolganda qoldiq {son1%son2}ga bolinma {son1//son2}ga teng")

# %%
#9
ism=input("Ismingizni kiriting ")
yosh=int(input("yoshingizni kiriting "))
sevimli_raqam=int(input("Sevimli raqamingizni kiriting "))
hozirgi_yil=int(input("Hozirgi yilni kiriting "))
print(f"Men {ism}man. Mening yoshim {yosh}da. Sevimli raqamim {sevimli_raqam}. Hozir {hozirgi_yil}-yil")

# %%
#10
yosh=int(input("yoshingizni kiriting "))
t_yil=2025-yosh
print(f"Siz {t_yil}da tug'ilgan ekansiz")

# %%
#11
ism=input("Ismingiz nima? ")
print(f"👋 Salom {ism}!")

# %%
#12
a = 42
b = 3.14
c = "Python"
d = True
print(f"dtype a--> {type(a)}")
print(f"dtype b--> {type(b)}")
print(f"dtype c--> {type(c)}")
print(f"dtype d--> {type(d)}")

# %%
#13
son1=float(input("Birinchi sonni kiriting "))
son2=float(input("Ikkinchi sonni kiriting "))
print(f"Sonlar yig'indisi {son1+son2}")
print(f"Sonlar ayirmasi {son1-son2}")
print(f"Sonlar ko'paytmai {son1*son2}")
print(f"Sonlar bo'linmasi {son1/son2}")
