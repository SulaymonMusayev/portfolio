# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("bankcustomerdata.csv")

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 3948     15743818           748    Spain    Male   58       9  122330.70
# 5203     15633866           753  Germany    Male   30       1  110824.52
# 3110     15707596           546  Germany  Female   74       8  114888.74
# 6674     15759034           654   France    Male   36       2  112262.84
# 1449     15726556           594  Germany  Female   26       6  135067.52
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 3948                2            0              1         124429.19      0
# 5203                1            1              1          57896.27      0
# 3110                2            1              1          66732.63      1
# 6674                1            1              0          12873.39      0
# 1449                2            0              0         131211.86      0

# %%
df_france = df[df['country'] == 'France']

# %%
df_spain = df[df['country'] == 'Spain']

# %%
df_germany = df[df['country'] == 'Germany']

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.dtypes
# Out:
# customer_id           int64
# credit_score          int64
# country              object
# gender               object
# age                   int64
# tenure                int64
# balance             float64
# products_number       int64
# credit_card           int64
# active_member         int64
# estimated_salary    float64
# churn                 int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
(df['balance'] == 0).value_counts()
# Out:
# balance
# False    6383
# True     3617
# Name: count, dtype: int64

# %%
df['credit_score'].min()
# Out:
# 350

# %%
df['credit_score'].max()
# Out:
# 850

# %%
df['credit_score'].mean()
# Out:
# np.float64(650.5288)

# %%
df['credit_score'].median()
# Out:
# 652.0

# %%
df['age'].min()
# Out:
# 18

# %%
df['age'].max()
# Out:
# 92

# %%
df['age'].mean()
# Out:
# np.float64(38.9218)

# %%
df['age'].median()
# Out:
# 37.0

# %%
df['balance'].min()
# Out:
# 0.0

# %%
df['balance'].max()
# Out:
# 250898.09

# %%
df['balance'].mean()
# Out:
# np.float64(76485.889288)

# %%
df['balance'].median()
# Out:
# 97198.54000000001

# %%
##Анализ и очистка данных:  jadval ma'lumotiga kora minimal kredit score 350, maksimal 850, o'rta credit score 650.5288, medianasi 652.0
##mijozlarning minimal yoshi 18, maksimal yoshi 92, mijozlarning o'rtacha yoshi 38.9218, medianasi 37.0
##mijoz balansidagi eng minimal qiymat 0, maksimal qiymat 250898.09, mijozlar balansidagi o'rtacha qiymat 76485.889288, medianasi 97198.54000000001

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['credit_score'], bins=30, kde=True, color='skyblue')
plt.title(" ")
plt.xlabel("Kredit reytingi")
plt.ylabel("Mijozlar soni")
plt.show()

# %%
##сегментация клиентов францию

# %%
df_france['customer_id'].nunique()
# Out:
# 5014

# %%
df_france['churn'].sum()
# Out:
# np.int64(810)

# %%
df_france['balance'].mean()
# Out:
# np.float64(62092.63651575588)

# %%
(df_france[['gender']]=='Male').value_counts()
# Out:
# gender
# True      2753
# False     2261
# Name: count, dtype: int64

# %%
df_france['age'].isin([18, 30]).value_counts()
# Out:
# age
# False    4831
# True      183
# Name: count, dtype: int64

# %%
df_france['age'].isin([31, 45]).value_counts()
# Out:
# age
# False    4696
# True      318
# Name: count, dtype: int64

# %%
df_france['age'].isin([46,60]).value_counts()
# Out:
# age
# False    4870
# True      144
# Name: count, dtype: int64

# %%
df_france['age'].isin([60, ]).value_counts()
# Out:
# age
# False    4971
# True       43
# Name: count, dtype: int64

# %%
df_france.loc[df_france['age'].isin([18, 30]), 'churn'].value_counts()
# Out:
# churn
# 0    176
# 1      7
# Name: count, dtype: int64

# %%
df_france.loc[df_france['age'].isin([31, 45]), 'churn'].value_counts()
# Out:
# churn
# 0    275
# 1     43
# Name: count, dtype: int64

# %%
df_france.loc[df_france['age'].isin([45, 60]), 'churn'].value_counts()
# Out:
# churn
# 0    92
# 1    51
# Name: count, dtype: int64

# %%
df_france.loc[df_france['age'].isin([60, ]), 'churn'].value_counts()
# Out:
# churn
# 1    22
# 0    21
# Name: count, dtype: int64

# %%
## germaniyalik 5014ta mijoz bolgan hozir shularning 810tasi faol. Fransiyalik mijozlarning o'rtacha balansi 62092. Mijozlar: 2753ta ayol 2261ta erkak
## mijozlarning yosh boyicha taqsimlarishi: 18:30 = 183, 31:45 = 318, 46:60 = 144, 60: = 43

# %%
## Анализ финансового поведения

# %%
df_france.groupby('churn')['balance'].mean()
# Out:
# churn
# 0    60339.275678
# 1    71192.795728
# Name: balance, dtype: float64

# %%
df['estimated_salary'].mean()
# Out:
# np.float64(100090.239881)

# %%
df_france['churn'].corr(df_france['balance'])
# Out:
# np.float64(0.062289963095771526)

# %%
df_france.groupby('products_number')['churn'].mean()
# Out:
# products_number
# 1    0.224344
# 2    0.057034
# 3    0.788462
# 4    1.000000
# Name: churn, dtype: float64

# %%
## Fransiya:
## Hozirda aktiv bolmaganlarning o'rtacha balansi: 60339.275678,
## aktivlarining o'rtacha balansi: 71192.795728
## mijozlar daromadining o'rta qiymati: 100090.239881
## mijozlarning hizmatlardan foydalanishi hozirgi faollikka bogliq emas

# %%
df_france.groupby('churn').mean(numeric_only=True)
# Out:
#         customer_id  credit_score        age    tenure       balance  \
# churn
# 0      1.569027e+07    651.162226  37.235966  5.005471  60339.275678
# 1      1.569262e+07    641.914815  45.133333  5.000000  71192.795728
#
#        products_number  credit_card  active_member  estimated_salary
# churn
# 0             1.541389     0.707422       0.545433      99217.097331
# 1             1.476543     0.702469       0.367901     103439.278296

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='churn', data=df_france)
plt.title("Churn bo‘yicha mijozlar soni")
plt.xlabel("Churn (0 = ketmagan, 1 = ketgan)")
plt.ylabel("Mijozlar soni")
plt.show()
